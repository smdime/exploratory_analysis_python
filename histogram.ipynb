# %%
import pandas as pd
import matplotlib.pyplot as plt #to clean out showing the array

# %%
df = pd.read_csv("sample_dataset.csv")

# %%
df.hist()

plt.show()

# %%
df.iloc[:,0:4].hist() #histogram of the first 4 columns
# Out:
# array([[<Axes: title={'center': 'mean radius'}>,
#         <Axes: title={'center': 'mean texture'}>],
#        [<Axes: title={'center': 'mean perimeter'}>,
#         <Axes: title={'center': 'mean area'}>]], dtype=object)

# %%
df.iloc[:,0:4].hist(bins=20) #manipulate the number of bins
# Out:
# array([[<Axes: title={'center': 'mean radius'}>,
#         <Axes: title={'center': 'mean texture'}>],
#        [<Axes: title={'center': 'mean perimeter'}>,
#         <Axes: title={'center': 'mean area'}>]], dtype=object)

# %%
df.iloc[:,0:4].hist(bins=200)
# Out:
# array([[<Axes: title={'center': 'mean radius'}>,
#         <Axes: title={'center': 'mean texture'}>],
#        [<Axes: title={'center': 'mean perimeter'}>,
#         <Axes: title={'center': 'mean area'}>]], dtype=object)

# %%
df.iloc[:,0:4].hist(bins=2)
# Out:
# array([[<Axes: title={'center': 'mean radius'}>,
#         <Axes: title={'center': 'mean texture'}>],
#        [<Axes: title={'center': 'mean perimeter'}>,
#         <Axes: title={'center': 'mean area'}>]], dtype=object)

# %%
df.iloc[:,0:4].hist(bins="rice")
# Out:
# array([[<Axes: title={'center': 'mean radius'}>,
#         <Axes: title={'center': 'mean texture'}>],
#        [<Axes: title={'center': 'mean perimeter'}>,
#         <Axes: title={'center': 'mean area'}>]], dtype=object)

# %%
df['area error'].value_counts().plot(kind="bar") #plot the count
# Out:
# <Axes: xlabel='area error'>
