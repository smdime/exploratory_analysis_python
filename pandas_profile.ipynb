# %%
# !pip3 install pandas-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# ...
#   Using cached joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# ...
#   Using cached pydantic-2.5.2-py3-none-any.whl.metadata (65 kB)
# ...
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# ...
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# ...
#   Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# ...
#   Using cached phik-0.12.3.tar.gz (620 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# ...
#   Using cached multimethod-1.10-py3-none-any.whl.metadata (8.2 kB)
# ...

# %%
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
df = pd.read_csv("sample_dataset.csv")

# %%
report = ProfileReport(df.iloc[:,0:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 report = ProfileReport(df.iloc[:,0:5])
#
# NameError: name 'ProfileReport' is not defined

# %%
report.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 report.to_notebook_iframe()
#
# NameError: name 'report' is not defined

# %%
report.to_file("report.html", silent=False) #to export the file or open to another window
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 report.to_file("report.html", silent=False) #to export the file or open to another window
#
# NameError: name 'report' is not defined

# %%
report = ProfileReport(df.iloc[:,0:5], minimal=True)
report.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 report = ProfileReport(df.iloc[:,0:5], minimal=True)
#       2 report.to_notebook_iframe()
#
# NameError: name 'ProfileReport' is not defined
